# %%
from random import uniform
import math

All_Lost = 0
BasicOptOfferPrice = 35
BasicOptOfferVol = 50
BasicStore = 80
InitAccount = 10000
InitQualification = 10
Max_Qualification = 100
Max_Demand = 30
MeanDPrice = 100
OptOfferAcceptDecision = 1 # Bool
OptOfferBaseVolume = 40
RentRate = 200
Ret_Price = 100  # Розничная цена
ShopStore = 30
STOP_SELL = 0 # Bool
TransferDecision = 1 # Bool
TransferRate = 150
TransferVol = 30 # Объем перевозки
VagesAndTaxes = 500
dt = 1
TIME = 0

# %%
timer = 100

Account = InitAccount
Qualification = InitQualification

BasicPriceRnd = BasicOptOfferVol * (uniform(.7, 1.3))
AddPriceByTime = BasicOptOfferPrice * 0.03 * TIME + BasicOptOfferPrice * 0.01 * TIME * uniform(0, 1)
OfferOnePrice = AddPriceByTime + BasicPriceRnd
RndOfferVolume = round(OptOfferBaseVolume * uniform(0.75, 1.25))
OfferFullPrice = OfferOnePrice * RndOfferVolume
OfferAcceptPossibility = 1 if Account >= OfferFullPrice else 0
SmallOptIncom = OfferAcceptPossibility * OptOfferAcceptDecision * RndOfferVolume

TransferActualVolue = min(BasicStore, TransferVol * TransferDecision) if Account >= TransferRate else 0
GoodsTransfer = math.floor(TransferActualVolue)
Lost = ShopStore + GoodsTransfer - 100 if ShopStore + GoodsTransfer > 100 else 0

QualSpending = round(Account * uniform(0.05, 0.2))
IncreaseQual = min(Max_Qualification-Qualification, (QualSpending/Account)*10)

Demand = round(Max_Demand * (1 - 1 / (1 + Qualification/Max_Qualification*10 + math.exp(-0.05 * (Ret_Price - MeanDPrice)))))
RND_Demand = round(Demand * uniform(0.7, 1.2))
SoldRet = (1 - STOP_SELL) * min(RND_Demand, ShopStore)
Selling = SoldRet
Income = Ret_Price * SoldRet

DailySpending = min(RentRate + VagesAndTaxes, Account)
TransSpend = TransferRate if TransferActualVolue > 0 else 0

print("-----------INITIAL DATA-----------")
print("-----------LEVEL VALUES-----------")
print(f"Account = {Account}")
print(f"BasicStore = {BasicStore}")
print(f"ShopStore = {ShopStore}")
print(f"Qualification = {Qualification}")
print("---------CHANGEABLE VALUES--------")
print(f"TransferVolume = {TransferVol}")
print(f"Ret_Price = {Ret_Price}")
print(f"STOP_SELL = {bool(STOP_SELL)}")
print(f"OptOfferAcceptDecision = {bool(OptOfferAcceptDecision)}")
print(f"TransferDecision = {bool(TransferDecision)}")
print("---------AUXILIARY VALUES---------")
print(f"RndOfferVolume = {RndOfferVolume}")
print(f"OfferFullPrice = {OfferFullPrice}")
print(f"OfferOnePrice = {OfferOnePrice}")
print(f"RND_Demand = {RND_Demand}")
print()
# Out:
# -----------INITIAL DATA-----------
# -----------LEVEL VALUES-----------
# Account = 10000
# BasicStore = 80
# ShopStore = 30
# Qualification = 10
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 1409.4260584730778
# OfferOnePrice = 35.23565146182695
# RND_Demand = 17

# %%
def params_changing(text):
    if input(text).lower() == 'y':
        return True
    else:
        return False

# %%
account_data = [Account]
qualification_data = [Qualification]
demand_data = [Demand]

flag = params_changing("Do you want to change parameters during process? Y/N")

for TIME in range(1, timer + 1):
    if flag:
        change_params = params_changing(f'Do you want to change parameters on {TIME} itereration?')
        if change_params:
            TransferVol = float(input(f"Write TransferVolume"))
            Ret_Price = float(input(f"Write Ret_Price"))
            STOP_SELL = 1 if input(f"Write STOP_SELL (y/n)").lower() == 'y' else 0
            OptOfferAcceptDecision = 1 if input(f"Write OptOfferAcceptDecision (y/n)").lower() == 'y' else 0
            TransferDecision = 1 if input(f"Write TransferDecision (y/n)").lower() == 'y' else 0
    Account += dt * (Income - DailySpending - TransSpend - QualSpending)
    BasicStore += dt * (SmallOptIncom - GoodsTransfer)
    ShopStore += dt * (GoodsTransfer - Selling - Lost)
    Qualification += dt * IncreaseQual
    All_Lost += dt * Lost

    BasicPriceRnd = BasicOptOfferVol * (uniform(.7, 1.3))
    AddPriceByTime = BasicOptOfferPrice * 0.03 * TIME + BasicOptOfferPrice * 0.01 * TIME * uniform(0, 1)
    OfferOnePrice = AddPriceByTime + BasicPriceRnd
    RndOfferVolume = round(OptOfferBaseVolume * uniform(0.75, 1.25))
    OfferFullPrice = OfferOnePrice * RndOfferVolume
    OfferAcceptPossibility = 1 if Account >= OfferFullPrice else 0
    SmallOptIncom = OfferAcceptPossibility * OptOfferAcceptDecision * RndOfferVolume

    TransferActualVolue = min(BasicStore, TransferVol * TransferDecision) if Account >= TransferRate else 0
    GoodsTransfer = math.floor(TransferActualVolue)
    Lost = ShopStore + GoodsTransfer - 100 if ShopStore + GoodsTransfer > 100 else 0

    QualSpending = round(Account * uniform(0.05, 0.2))
    IncreaseQual = min(Max_Qualification-Qualification, (QualSpending/Account)*10)

    Demand = round(Max_Demand * (1 - 1 / (1 + Qualification/Max_Qualification*10 + math.exp(-0.05 * (Ret_Price - MeanDPrice)))))
    RND_Demand = round(Demand * uniform(0.7, 1.2))
    SoldRet = (1 - STOP_SELL) * min(RND_Demand, ShopStore)
    Selling = SoldRet
    Income = Ret_Price * SoldRet

    DailySpending = min(RentRate+VagesAndTaxes, Account)
    TransSpend = TransferRate if TransferActualVolue > 0 else 0

    account_data.append(Account)
    qualification_data.append(Qualification)
    demand_data.append(Demand)

    print(f"-------DATA ON STEP {TIME}-------")
    print("-----------LEVEL VALUES-----------")
    print(f"Account = {Account}")
    print(f"BasicStore = {BasicStore}")
    print(f"ShopStore = {ShopStore}")
    print(f"Qualification = {Qualification}")
    print("---------CHANGEABLE VALUES--------")
    print(f"TransferVolume = {TransferVol}")
    print(f"Ret_Price = {Ret_Price}")
    print(f"STOP_SELL = {bool(STOP_SELL)}")
    print(f"OptOfferAcceptDecision = {bool(OptOfferAcceptDecision)}")
    print(f"TransferDecision = {bool(TransferDecision)}")
    print("---------AUXILIARY VALUES---------")
    print(f"RndOfferVolume = {RndOfferVolume}")
    print(f"OfferFullPrice = {OfferFullPrice}")
    print(f"OfferOnePrice = {OfferOnePrice}")
    print(f"RND_Demand = {RND_Demand}")
    print()
# Out:
# -------DATA ON STEP 1-------
# -----------LEVEL VALUES-----------
# Account = 10248
# BasicStore = 90
# ShopStore = 43
# Qualification = 10.602
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 2598.1954823946426
# OfferOnePrice = 57.73767738654762
# RND_Demand = 22
#
# -------DATA ON STEP 2-------
# -----------LEVEL VALUES-----------
# Account = 10258
# BasicStore = 105
# ShopStore = 51
# Qualification = 11.909572209211554
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 1875.0435591706357
# OfferOnePrice = 43.60566416675897
# RND_Demand = 21
#
# -------DATA ON STEP 3-------
# -----------LEVEL VALUES-----------
# Account = 10603
# BasicStore = 118
# ShopStore = 60
# Qualification = 12.791810462282328
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 3183.381469038781
# OfferOnePrice = 64.96696875589349
# RND_Demand = 17
#
# -------DATA ON STEP 4-------
# -----------LEVEL VALUES-----------
# Account = 10885
# BasicStore = 137
# ShopStore = 73
# Qualification = 13.327507906401916
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 2122.3188278646976
# OfferOnePrice = 58.95330077401938
# RND_Demand = 18
#
# -------DATA ON STEP 5-------
# -----------LEVEL VALUES-----------
# Account = 10601
# BasicStore = 143
# ShopStore = 82
# Qualification = 14.461178094734484
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 1799.3249992995986
# OfferOnePrice = 58.04274191289028
# RND_Demand = 23
#
# -------DATA ON STEP 6-------
# -----------LEVEL VALUES-----------
# Account = 11010
# BasicStore = 144
# ShopStore = 77
# Qualification = 15.443160926542804
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 2366.900190903182
# OfferOnePrice = 56.354766450075765
# RND_Demand = 26
#
# -------DATA ON STEP 7-------
# -----------LEVEL VALUES-----------
# Account = 11174
# BasicStore = 156
# ShopStore = 74
# Qualification = 16.883669555062333
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 3254.2744474203178
# OfferOnePrice = 72.31720994267373
# RND_Demand = 22
#
# -------DATA ON STEP 8-------
# -----------LEVEL VALUES-----------
# Account = 11681
# BasicStore = 171
# ShopStore = 78
# Qualification = 17.638099481677692
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 2800.373758578824
# OfferOnePrice = 71.80445534817497
# RND_Demand = 18
#
# -------DATA ON STEP 9-------
# -----------LEVEL VALUES-----------
# Account = 10796
# BasicStore = 180
# ShopStore = 82
# Qualification = 19.209026628326097
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 2376.814661251114
# OfferOnePrice = 67.90899032146041
# RND_Demand = 16
#
# -------DATA ON STEP 10-------
# -----------LEVEL VALUES-----------
# Account = 10794
# BasicStore = 185
# ShopStore = 84
# Qualification = 19.905580907688822
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 2134.501652724741
# OfferOnePrice = 50.82146792201764
# RND_Demand = 19
#
# -------DATA ON STEP 11-------
# -----------LEVEL VALUES-----------
# Account = 9901
# BasicStore = 197
# ShopStore = 81
# Qualification = 21.705655022938036
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 2702.876154556331
# OfferOnePrice = 69.30451678349567
# RND_Demand = 19
#
# -------DATA ON STEP 12-------
# -----------LEVEL VALUES-----------
# Account = 10090
# BasicStore = 206
# ShopStore = 81
# Qualification = 22.575264153328906
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 2194.296273152817
# OfferOnePrice = 59.305304679805865
# RND_Demand = 23
#
# -------DATA ON STEP 13-------
# -----------LEVEL VALUES-----------
# Account = 10103
# BasicStore = 213
# ShopStore = 77
# Qualification = 23.999446512099965
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 2787.469309103426
# OfferOnePrice = 73.35445550272173
# RND_Demand = 18
#
# -------DATA ON STEP 14-------
# -----------LEVEL VALUES-----------
# Account = 9710
# BasicStore = 221
# ShopStore = 82
# Qualification = 25.328754638399083
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 3195.521720530859
# OfferOnePrice = 65.2147289904257
# RND_Demand = 19
#
# -------DATA ON STEP 15-------
# -----------LEVEL VALUES-----------
# Account = 10113
# BasicStore = 240
# ShopStore = 81
# Qualification = 25.995078016359948
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 3599.2178303323967
# OfferOnePrice = 83.70274024028829
# RND_Demand = 22
#
# -------DATA ON STEP 16-------
# -----------LEVEL VALUES-----------
# Account = 9972
# BasicStore = 253
# ShopStore = 78
# Qualification = 27.469417974829245
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 2189.5718922672536
# OfferOnePrice = 70.6313513634598
# RND_Demand = 22
#
# -------DATA ON STEP 17-------
# -----------LEVEL VALUES-----------
# Account = 10423
# BasicStore = 254
# ShopStore = 78
# Qualification = 28.370942242779506
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 32
# OfferFullPrice = 1861.5929474493523
# OfferOnePrice = 58.17477960779226
# RND_Demand = 17
#
# -------DATA ON STEP 18-------
# -----------LEVEL VALUES-----------
# Account = 10375
# BasicStore = 256
# ShopStore = 83
# Qualification = 29.23249841662581
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 34
# OfferFullPrice = 2995.879523640485
# OfferOnePrice = 88.11410363648486
# RND_Demand = 20
#
# -------DATA ON STEP 19-------
# -----------LEVEL VALUES-----------
# Account = 10656
# BasicStore = 260
# ShopStore = 80
# Qualification = 30.070088778071593
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 3414.365615444596
# OfferOnePrice = 83.27721013279503
# RND_Demand = 23
#
# -------DATA ON STEP 20-------
# -----------LEVEL VALUES-----------
# Account = 10126
# BasicStore = 271
# ShopStore = 77
# Qualification = 31.928196886179702
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 2875.176703833892
# OfferOnePrice = 70.12626106911932
# RND_Demand = 24
#
# -------DATA ON STEP 21-------
# -----------LEVEL VALUES-----------
# Account = 9707
# BasicStore = 282
# ShopStore = 76
# Qualification = 33.872696194889954
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 2981.2947119825735
# OfferOnePrice = 62.11030649963695
# RND_Demand = 23
#
# -------DATA ON STEP 22-------
# -----------LEVEL VALUES-----------
# Account = 9654
# BasicStore = 300
# ShopStore = 77
# Qualification = 35.421063352611185
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 3492.6004742447717
# OfferOnePrice = 71.27756069887289
# RND_Demand = 23
#
# -------DATA ON STEP 23-------
# -----------LEVEL VALUES-----------
# Account = 10050
# BasicStore = 319
# ShopStore = 77
# Qualification = 36.51283878248481
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 4248.785189514453
# OfferOnePrice = 90.39968488328624
# RND_Demand = 19
#
# -------DATA ON STEP 24-------
# -----------LEVEL VALUES-----------
# Account = 9198
# BasicStore = 336
# ShopStore = 81
# Qualification = 38.405376095917646
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 3471.9768102466414
# OfferOnePrice = 78.90856386924185
# RND_Demand = 19
#
# -------DATA ON STEP 25-------
# -----------LEVEL VALUES-----------
# Account = 9044
# BasicStore = 350
# ShopStore = 81
# Qualification = 39.71435630900745
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 3408.312433237508
# OfferOnePrice = 87.39262649326943
# RND_Demand = 21
#
# -------DATA ON STEP 26-------
# -----------LEVEL VALUES-----------
# Account = 9288
# BasicStore = 359
# ShopStore = 79
# Qualification = 40.826695981718636
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 3681.726187870015
# OfferOnePrice = 76.70262891395865
# RND_Demand = 30
#
# -------DATA ON STEP 27-------
# -----------LEVEL VALUES-----------
# Account = 10141
# BasicStore = 377
# ShopStore = 70
# Qualification = 42.22312147698134
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 3292.202967950549
# OfferOnePrice = 76.5628597197802
# RND_Demand = 29
#
# -------DATA ON STEP 28-------
# -----------LEVEL VALUES-----------
# Account = 10961
# BasicStore = 390
# ShopStore = 71
# Qualification = 43.436019613259816
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 4161.795735750321
# OfferOnePrice = 90.47382034239828
# RND_Demand = 23
#
# -------DATA ON STEP 29-------
# -----------LEVEL VALUES-----------
# Account = 11528
# BasicStore = 406
# ShopStore = 77
# Qualification = 44.24160304542841
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 4637.755592615913
# OfferOnePrice = 98.67565090672154
# RND_Demand = 23
#
# -------DATA ON STEP 30-------
# -----------LEVEL VALUES-----------
# Account = 12154
# BasicStore = 423
# ShopStore = 77
# Qualification = 44.956384447232715
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 4325.079511425248
# OfferOnePrice = 92.02296832819675
# RND_Demand = 24
#
# -------DATA ON STEP 31-------
# -----------LEVEL VALUES-----------
# Account = 11342
# BasicStore = 440
# ShopStore = 76
# Qualification = 46.89977756883877
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 4632.7002790425395
# OfferOnePrice = 100.71087563135956
# RND_Demand = 23
#
# -------DATA ON STEP 32-------
# -----------LEVEL VALUES-----------
# Account = 11099
# BasicStore = 456
# ShopStore = 77
# Qualification = 48.39245963549368
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 3724.873667292884
# OfferOnePrice = 86.62496900681126
# RND_Demand = 27
#
# -------DATA ON STEP 33-------
# -----------LEVEL VALUES-----------
# Account = 11460
# BasicStore = 469
# ShopStore = 73
# Qualification = 49.73402193840385
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 3506.462894762001
# OfferOnePrice = 106.25645135642426
# RND_Demand = 23
#
# -------DATA ON STEP 34-------
# -----------LEVEL VALUES-----------
# Account = 12008
# BasicStore = 472
# ShopStore = 77
# Qualification = 50.52110745323805
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 3748.0675697381703
# OfferOnePrice = 85.18335385768569
# RND_Demand = 20
#
# -------DATA ON STEP 35-------
# -----------LEVEL VALUES-----------
# Account = 12523
# BasicStore = 486
# ShopStore = 80
# Qualification = 51.04992157715544
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 4836.4718462884875
# OfferOnePrice = 107.47715213974418
# RND_Demand = 25
#
# -------DATA ON STEP 36-------
# -----------LEVEL VALUES-----------
# Account = 11880
# BasicStore = 501
# ShopStore = 75
# Qualification = 52.880952480293665
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 4985.3521228262825
# OfferOnePrice = 106.07132176226133
# RND_Demand = 25
#
# -------DATA ON STEP 37-------
# -----------LEVEL VALUES-----------
# Account = 12458
# BasicStore = 518
# ShopStore = 75
# Qualification = 53.783309382650565
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 4527.856171961375
# OfferOnePrice = 107.80609933241371
# RND_Demand = 21
#
# -------DATA ON STEP 38-------
# -----------LEVEL VALUES-----------
# Account = 12781
# BasicStore = 530
# ShopStore = 79
# Qualification = 54.52740955924392
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 4067.9980848808045
# OfferOnePrice = 112.99994680224457
# RND_Demand = 19
#
# -------DATA ON STEP 39-------
# -----------LEVEL VALUES-----------
# Account = 12034
# BasicStore = 536
# ShopStore = 81
# Qualification = 55.93340283050595
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 4623.479318774375
# OfferOnePrice = 102.74398486165279
# RND_Demand = 25
#
# -------DATA ON STEP 40-------
# -----------LEVEL VALUES-----------
# Account = 11589
# BasicStore = 551
# ShopStore = 75
# Qualification = 57.67430361162611
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 3231.261243685984
# OfferOnePrice = 97.91700738442375
# RND_Demand = 22
#
# -------DATA ON STEP 41-------
# -----------LEVEL VALUES-----------
# Account = 11589
# BasicStore = 554
# ShopStore = 78
# Qualification = 58.83920135949046
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 31
# OfferFullPrice = 3358.360840403774
# OfferOnePrice = 108.33422065818627
# RND_Demand = 19
#
# -------DATA ON STEP 42-------
# -----------LEVEL VALUES-----------
# Account = 10864
# BasicStore = 555
# ShopStore = 81
# Qualification = 60.370826176126926
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 3883.2304780017294
# OfferOnePrice = 97.08076195004324
# RND_Demand = 19
#
# -------DATA ON STEP 43-------
# -----------LEVEL VALUES-----------
# Account = 11161
# BasicStore = 565
# ShopStore = 81
# Qualification = 61.06394105094283
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 4785.087762758008
# OfferOnePrice = 116.7094576282441
# RND_Demand = 18
#
# -------DATA ON STEP 44-------
# -----------LEVEL VALUES-----------
# Account = 10448
# BasicStore = 576
# ShopStore = 82
# Qualification = 62.553950906690524
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 3896.214374918322
# OfferOnePrice = 88.55032670268913
# RND_Demand = 19
#
# -------DATA ON STEP 45-------
# -----------LEVEL VALUES-----------
# Account = 10040
# BasicStore = 590
# ShopStore = 81
# Qualification = 63.94943329566449
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 3520.7714095401607
# OfferOnePrice = 97.79920582056002
# RND_Demand = 22
#
# -------DATA ON STEP 46-------
# -----------LEVEL VALUES-----------
# Account = 9872
# BasicStore = 596
# ShopStore = 78
# Qualification = 65.46138548689954
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 4438.192518712622
# OfferOnePrice = 96.48244605897003
# RND_Demand = 24
#
# -------DATA ON STEP 47-------
# -----------LEVEL VALUES-----------
# Account = 10564
# BasicStore = 612
# ShopStore = 76
# Qualification = 66.33051028430636
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 50
# OfferFullPrice = 5696.501903606384
# OfferOnePrice = 113.93003807212767
# RND_Demand = 31
#
# -------DATA ON STEP 48-------
# -----------LEVEL VALUES-----------
# Account = 12256
# BasicStore = 632
# ShopStore = 69
# Qualification = 66.85871929604434
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 4613.930066522795
# OfferOnePrice = 115.34825166306986
# RND_Demand = 29
#
# -------DATA ON STEP 49-------
# -----------LEVEL VALUES-----------
# Account = 13532
# BasicStore = 642
# ShopStore = 70
# Qualification = 67.49024671118795
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 4201.650005439921
# OfferOnePrice = 89.3968086263813
# RND_Demand = 25
#
# -------DATA ON STEP 50-------
# -----------LEVEL VALUES-----------
# Account = 12890
# BasicStore = 659
# ShopStore = 75
# Qualification = 69.18400964349655
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 5382.004911397856
# OfferOnePrice = 117.00010676951861
# RND_Demand = 28
#
# -------DATA ON STEP 51-------
# -----------LEVEL VALUES-----------
# Account = 13970
# BasicStore = 675
# ShopStore = 72
# Qualification = 69.85895145885729
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 34
# OfferFullPrice = 4134.315302299173
# OfferOnePrice = 121.59750889115215
# RND_Demand = 22
#
# -------DATA ON STEP 52-------
# -----------LEVEL VALUES-----------
# Account = 12840
# BasicStore = 679
# ShopStore = 78
# Qualification = 71.63418410023166
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 4741.843704193639
# OfferOnePrice = 105.3743045376364
# RND_Demand = 22
#
# -------DATA ON STEP 53-------
# -----------LEVEL VALUES-----------
# Account = 12253
# BasicStore = 694
# ShopStore = 78
# Qualification = 73.14275107842481
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 4051.382534964265
# OfferOnePrice = 122.76916772618983
# RND_Demand = 23
#
# -------DATA ON STEP 54-------
# -----------LEVEL VALUES-----------
# Account = 12298
# BasicStore = 697
# ShopStore = 77
# Qualification = 74.2894090397404
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 4720.205371520462
# OfferOnePrice = 115.12696028098688
# RND_Demand = 27
#
# -------DATA ON STEP 55-------
# -----------LEVEL VALUES-----------
# Account = 12181
# BasicStore = 708
# ShopStore = 73
# Qualification = 75.88885610430376
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 4800.323925910411
# OfferOnePrice = 111.63544013745143
# RND_Demand = 29
#
# -------DATA ON STEP 56-------
# -----------LEVEL VALUES-----------
# Account = 12319
# BasicStore = 721
# ShopStore = 71
# Qualification = 77.45851376787817
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 4135.024371466166
# OfferOnePrice = 114.86178809628237
# RND_Demand = 31
#
# -------DATA ON STEP 57-------
# -----------LEVEL VALUES-----------
# Account = 12287
# BasicStore = 727
# ShopStore = 69
# Qualification = 79.31093685416765
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 6164.505485884442
# OfferOnePrice = 125.80623440580494
# RND_Demand = 32
#
# -------DATA ON STEP 58-------
# -----------LEVEL VALUES-----------
# Account = 13287
# BasicStore = 746
# ShopStore = 67
# Qualification = 80.40965908091137
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 5228.8323224979795
# OfferOnePrice = 113.67026788039087
# RND_Demand = 21
#
# -------DATA ON STEP 59-------
# -----------LEVEL VALUES-----------
# Account = 12002
# BasicStore = 762
# ShopStore = 76
# Qualification = 82.31753896350338
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 4061.6884789832334
# OfferOnePrice = 106.8865389206114
# RND_Demand = 24
#
# -------DATA ON STEP 60-------
# -----------LEVEL VALUES-----------
# Account = 11344
# BasicStore = 770
# ShopStore = 76
# Qualification = 84.15723234793931
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 4984.584332751426
# OfferOnePrice = 127.809854685934
# RND_Demand = 25
#
# -------DATA ON STEP 61-------
# -----------LEVEL VALUES-----------
# Account = 11510
# BasicStore = 779
# ShopStore = 75
# Qualification = 85.46541288390546
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 4640.460331415977
# OfferOnePrice = 122.1173771425257
# RND_Demand = 27
#
# -------DATA ON STEP 62-------
# -----------LEVEL VALUES-----------
# Account = 11282
# BasicStore = 787
# ShopStore = 73
# Qualification = 87.27079950423561
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 5109.750289723758
# OfferOnePrice = 116.13068840281268
# RND_Demand = 23
#
# -------DATA ON STEP 63-------
# -----------LEVEL VALUES-----------
# Account = 11785
# BasicStore = 801
# ShopStore = 77
# Qualification = 88.11018968328187
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 49
# OfferFullPrice = 7003.495181336439
# OfferOnePrice = 142.92847308849875
# RND_Demand = 19
#
# -------DATA ON STEP 64-------
# -----------LEVEL VALUES-----------
# Account = 11153
# BasicStore = 820
# ShopStore = 81
# Qualification = 89.53742769770699
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 50
# OfferFullPrice = 5895.217404797204
# OfferOnePrice = 117.90434809594407
# RND_Demand = 30
#
# -------DATA ON STEP 65-------
# -----------LEVEL VALUES-----------
# Account = 11221
# BasicStore = 840
# ShopStore = 70
# Qualification = 91.40419000381297
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 5426.8688971638085
# OfferOnePrice = 142.8123393990476
# RND_Demand = 31
#
# -------DATA ON STEP 66-------
# -----------LEVEL VALUES-----------
# Account = 11643
# BasicStore = 848
# ShopStore = 69
# Qualification = 93.0332783203623
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 6156.054450509364
# OfferOnePrice = 139.91032842066735
# RND_Demand = 30
#
# -------DATA ON STEP 67-------
# -----------LEVEL VALUES-----------
# Account = 12192
# BasicStore = 862
# ShopStore = 69
# Qualification = 94.40835347281441
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 5560.7990008269735
# OfferOnePrice = 142.5845897647942
# RND_Demand = 21
#
# -------DATA ON STEP 68-------
# -----------LEVEL VALUES-----------
# Account = 12290
# BasicStore = 871
# ShopStore = 78
# Qualification = 95.35323536257819
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 5376.205582529921
# OfferOnePrice = 149.33904395916448
# RND_Demand = 22
#
# -------DATA ON STEP 69-------
# -----------LEVEL VALUES-----------
# Account = 12720
# BasicStore = 877
# ShopStore = 78
# Qualification = 96.10181144069048
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 45
# OfferFullPrice = 5569.546079017777
# OfferOnePrice = 123.76769064483949
# RND_Demand = 19
#
# -------DATA ON STEP 70-------
# -----------LEVEL VALUES-----------
# Account = 12882
# BasicStore = 892
# ShopStore = 81
# Qualification = 96.79992464823765
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 4013.0948405931986
# OfferOnePrice = 121.60893456343025
# RND_Demand = 23
#
# -------DATA ON STEP 71-------
# -----------LEVEL VALUES-----------
# Account = 13314
# BasicStore = 895
# ShopStore = 77
# Qualification = 97.5901746094238
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 33
# OfferFullPrice = 4483.664056841653
# OfferOnePrice = 135.8686077830804
# RND_Demand = 31
#
# -------DATA ON STEP 72-------
# -----------LEVEL VALUES-----------
# Account = 14693
# BasicStore = 898
# ShopStore = 69
# Qualification = 98.24437319737633
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 32
# OfferFullPrice = 4026.7648629182177
# OfferOnePrice = 125.8364019661943
# RND_Demand = 27
#
# -------DATA ON STEP 73-------
# -----------LEVEL VALUES-----------
# Account = 14094
# BasicStore = 900
# ShopStore = 72
# Qualification = 99.91115329674338
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 5393.842559281472
# OfferOnePrice = 131.55713559223102
# RND_Demand = 29
#
# -------DATA ON STEP 74-------
# -----------LEVEL VALUES-----------
# Account = 13351
# BasicStore = 911
# ShopStore = 71
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7075.293570543133
# OfferOnePrice = 147.40194938631527
# RND_Demand = 20
#
# -------DATA ON STEP 75-------
# -----------LEVEL VALUES-----------
# Account = 13136
# BasicStore = 929
# ShopStore = 80
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 47
# OfferFullPrice = 5380.548103221907
# OfferOnePrice = 114.47974687706184
# RND_Demand = 25
#
# -------DATA ON STEP 76-------
# -----------LEVEL VALUES-----------
# Account = 13403
# BasicStore = 946
# ShopStore = 75
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 34
# OfferFullPrice = 4778.523923328288
# OfferOnePrice = 140.54482127436142
# RND_Demand = 29
#
# -------DATA ON STEP 77-------
# -----------LEVEL VALUES-----------
# Account = 14459
# BasicStore = 950
# ShopStore = 71
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 4760.619869522073
# OfferOnePrice = 158.6873289840691
# RND_Demand = 22
#
# -------DATA ON STEP 78-------
# -----------LEVEL VALUES-----------
# Account = 13917
# BasicStore = 950
# ShopStore = 78
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 5459.1833526402015
# OfferOnePrice = 147.54549601730275
# RND_Demand = 24
#
# -------DATA ON STEP 79-------
# -----------LEVEL VALUES-----------
# Account = 14456
# BasicStore = 957
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 5958.153744771475
# OfferOnePrice = 129.52508140807555
# RND_Demand = 21
#
# -------DATA ON STEP 80-------
# -----------LEVEL VALUES-----------
# Account = 14206
# BasicStore = 973
# ShopStore = 79
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7906.122347968127
# OfferOnePrice = 164.71088224933598
# RND_Demand = 28
#
# -------DATA ON STEP 81-------
# -----------LEVEL VALUES-----------
# Account = 14315
# BasicStore = 991
# ShopStore = 72
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 38
# OfferFullPrice = 6130.1529492977625
# OfferOnePrice = 161.31981445520427
# RND_Demand = 30
#
# -------DATA ON STEP 82-------
# -----------LEVEL VALUES-----------
# Account = 14520
# BasicStore = 999
# ShopStore = 70
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 6446.648112772609
# OfferOnePrice = 161.16620281931523
# RND_Demand = 28
#
# -------DATA ON STEP 83-------
# -----------LEVEL VALUES-----------
# Account = 14831
# BasicStore = 1009
# ShopStore = 72
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7809.3481648397055
# OfferOnePrice = 162.69475343416053
# RND_Demand = 27
#
# -------DATA ON STEP 84-------
# -----------LEVEL VALUES-----------
# Account = 15594
# BasicStore = 1027
# ShopStore = 73
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 6527.173771251612
# OfferOnePrice = 135.98278690107526
# RND_Demand = 29
#
# -------DATA ON STEP 85-------
# -----------LEVEL VALUES-----------
# Account = 15896
# BasicStore = 1045
# ShopStore = 71
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 46
# OfferFullPrice = 7496.539380230442
# OfferOnePrice = 162.96824739631396
# RND_Demand = 26
#
# -------DATA ON STEP 86-------
# -----------LEVEL VALUES-----------
# Account = 14612
# BasicStore = 1061
# ShopStore = 74
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 42
# OfferFullPrice = 6063.93970110006
# OfferOnePrice = 144.37951669285857
# RND_Demand = 30
#
# -------DATA ON STEP 87-------
# -----------LEVEL VALUES-----------
# Account = 15015
# BasicStore = 1073
# ShopStore = 70
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 41
# OfferFullPrice = 6381.001466099289
# OfferOnePrice = 155.63418209998267
# RND_Demand = 21
#
# -------DATA ON STEP 88-------
# -----------LEVEL VALUES-----------
# Account = 15027
# BasicStore = 1084
# ShopStore = 79
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 35
# OfferFullPrice = 5686.517825071713
# OfferOnePrice = 162.4719378591918
# RND_Demand = 33
#
# -------DATA ON STEP 89-------
# -----------LEVEL VALUES-----------
# Account = 15118
# BasicStore = 1089
# ShopStore = 67
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 6247.701496929693
# OfferOnePrice = 168.85679721431603
# RND_Demand = 22
#
# -------DATA ON STEP 90-------
# -----------LEVEL VALUES-----------
# Account = 14892
# BasicStore = 1096
# ShopStore = 75
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 37
# OfferFullPrice = 6344.764303196252
# OfferOnePrice = 171.4801163026014
# RND_Demand = 32
#
# -------DATA ON STEP 91-------
# -----------LEVEL VALUES-----------
# Account = 15293
# BasicStore = 1103
# ShopStore = 68
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 6470.401497637843
# OfferOnePrice = 150.4744534334382
# RND_Demand = 20
#
# -------DATA ON STEP 92-------
# -----------LEVEL VALUES-----------
# Account = 14410
# BasicStore = 1116
# ShopStore = 78
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 8576.97746750254
# OfferOnePrice = 178.6870305729696
# RND_Demand = 27
#
# -------DATA ON STEP 93-------
# -----------LEVEL VALUES-----------
# Account = 14626
# BasicStore = 1134
# ShopStore = 73
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 44
# OfferFullPrice = 7683.422968501636
# OfferOnePrice = 174.6232492841281
# RND_Demand = 22
#
# -------DATA ON STEP 94-------
# -----------LEVEL VALUES-----------
# Account = 15025
# BasicStore = 1148
# ShopStore = 78
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 30
# OfferFullPrice = 4486.627512623607
# OfferOnePrice = 149.5542504207869
# RND_Demand = 32
#
# -------DATA ON STEP 95-------
# -----------LEVEL VALUES-----------
# Account = 15590
# BasicStore = 1148
# ShopStore = 68
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 36
# OfferFullPrice = 5842.341893315521
# OfferOnePrice = 162.28727481432003
# RND_Demand = 30
#
# -------DATA ON STEP 96-------
# -----------LEVEL VALUES-----------
# Account = 14839
# BasicStore = 1154
# ShopStore = 68
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 48
# OfferFullPrice = 7630.178428547852
# OfferOnePrice = 158.9620505947469
# RND_Demand = 21
#
# -------DATA ON STEP 97-------
# -----------LEVEL VALUES-----------
# Account = 13422
# BasicStore = 1172
# ShopStore = 77
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 43
# OfferFullPrice = 7537.980494532452
# OfferOnePrice = 175.301871965871
# RND_Demand = 26
#
# -------DATA ON STEP 98-------
# -----------LEVEL VALUES-----------
# Account = 13918
# BasicStore = 1185
# ShopStore = 74
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 39
# OfferFullPrice = 7004.554127474898
# OfferOnePrice = 179.60395198653586
# RND_Demand = 24
#
# -------DATA ON STEP 99-------
# -----------LEVEL VALUES-----------
# Account = 12709
# BasicStore = 1194
# ShopStore = 76
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 40
# OfferFullPrice = 6919.649826981077
# OfferOnePrice = 172.99124567452694
# RND_Demand = 22
#
# -------DATA ON STEP 100-------
# -----------LEVEL VALUES-----------
# Account = 12211
# BasicStore = 1204
# ShopStore = 78
# Qualification = 100.0
# ---------CHANGEABLE VALUES--------
# TransferVolume = 30
# Ret_Price = 100
# STOP_SELL = False
# OptOfferAcceptDecision = True
# TransferDecision = True
# ---------AUXILIARY VALUES---------
# RndOfferVolume = 32
# OfferFullPrice = 5916.730259407191
# OfferOnePrice = 184.8978206064747
# RND_Demand = 32

# %%
import matplotlib.pyplot as plt

# Создание первого графика для состояния счета и состояния налогов
plt.figure(figsize=(10, 6))

plt.subplot(2, 1, 1)
plt.plot(account_data, label='Состояние счета', color='blue')
plt.title('Состояние счета')
plt.legend()
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(qualification_data, label='Уровень квалификации', color='red')
plt.plot(demand_data, label='Уровень спроса', color='green')
plt.title('Уровень квалификации')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
